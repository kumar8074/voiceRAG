# %%
from langchain_community.document_loaders import PyMuPDFLoader
import os

# %%
# !pwd
# Out:
# /Users/sumi/Desktop/voiceRAG/notebooks

# %%
os.chdir("../")
# !pwd
# Out:
# /Users/sumi/Desktop/voiceRAG

# %%
loader = PyMuPDFLoader("tmp/83577772-b923-4c40-891d-2edd3fe26fad_Startup India Kit_v5.pdf")

# %%
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Adobe PDF library 15.00', 'creator': 'Adobe Illustrator CC 23.1 (Macintosh)', 'creationdate': '2019-10-23T16:50:47+05:30', 'source': 'tmp/83577772-b923-4c40-891d-2edd3fe26fad_Startup India Kit_v5.pdf', 'file_path': 'tmp/83577772-b923-4c40-891d-2edd3fe26fad_Startup India Kit_v5.pdf', 'total_pages': 20, 'format': 'PDF 1.5', 'title': 'Startup India Kit_v5_for web copy', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2019-10-23T16:50:47+05:30', 'trapped': '', 'modDate': "D:20191023165047+05'30'", 'creationDate': "D:20191023165047+05'30'", 'page': 0}, page_content='Starter kit for budding entrepreneurs,\n   visionaries and dreamers!\nSTARTUP INDIA KIT\nDated: October, 2019'),
# ...

# %%
type(docs)
# Out:
# list

# %%
docs[0].metadata
# Out:
# {'producer': 'Adobe PDF library 15.00',
#  'creator': 'Adobe Illustrator CC 23.1 (Macintosh)',
#  'creationdate': '2019-10-23T16:50:47+05:30',
#  'source': 'tmp/83577772-b923-4c40-891d-2edd3fe26fad_Startup India Kit_v5.pdf',
#  'file_path': 'tmp/83577772-b923-4c40-891d-2edd3fe26fad_Startup India Kit_v5.pdf',
#  'total_pages': 20,
#  'format': 'PDF 1.5',
#  'title': 'Startup India Kit_v5_for web copy',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'moddate': '2019-10-23T16:50:47+05:30',
#  'trapped': '',
#  'modDate': "D:20191023165047+05'30'",
#  'creationDate': "D:20191023165047+05'30'",
#  'page': 0}

# %%
docs[0].metadata["total_pages"], docs[0].metadata["title"], docs[0].metadata["page"]
# Out:
# (20, 'Startup India Kit_v5_for web copy', 0)
